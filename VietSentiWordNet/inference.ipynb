# %%
import evaluate
from datasets import disable_caching, load_from_disk
from transformers import (
    AutoTokenizer,
    pipeline,
)
from transformers.pipelines.pt_utils import KeyDataset

# %%
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base-v2")
test = load_from_disk("../data/test/")
accuracy = evaluate.load("accuracy")

# %%
classifier = pipeline(
    task="text-classification",
    model="./SentimentPhoBERT",
    tokenizer=tokenizer,
    device=0,
)
predictions = list(
    classifier(
        KeyDataset(test, "sentence"),
        padding=True,
        truncation=True,
        max_length=256,
        batch_size=8
    )
)
predictions = [
    int(prediction["label"].replace("LABEL_", "")) for prediction in predictions
]
accuracy.compute(predictions=predictions, references=test["labels"])
# Out:
# {'accuracy': 0.81175}

# %%
classifier = pipeline(
    task="text-classification",
    model="./SentimentPhoBERT-LoRA-150",
    tokenizer=tokenizer,
    device=0,
)
predictions = list(
    classifier(
        KeyDataset(test, "sentence"),
        padding=True,
        truncation=True,
        max_length=150,
        batch_size=8,
    )
)
predictions = [
    int(prediction["label"].replace("LABEL_", "")) for prediction in predictions
]
accuracy.compute(predictions=predictions, references=test["labels"])
# Out:
# {'accuracy': 0.89725}

# %%
classifier = pipeline(
    task="text-classification",
    model="./../SentimentPhoBERT-LoRA-256",
    tokenizer=tokenizer,
    device=0,
)

# %%
predictions = list(
    classifier(
        KeyDataset(test, "sentence"),
        padding=True,
        truncation=True,
        max_length=256,
        batch_size=8,
    )
)

# %%
import jnius_config

jnius_config.add_classpath(
    "libs/jvntextpro.jar",
    "libs/vietsentiwordnet_v1.0.jar",
)

from jnius import autoclass

# Load class
OpinionFinder = autoclass("vnu.uet.vietsentiwordnet.apis.OpinionFinder")
sl = OpinionFinder.getInstance().loadModels()
ResultObject = autoclass("vnu.uet.vietsentiwordnet.objects.ResultObject")
res = ResultObject()
javaclass_String = autoclass("java.lang.String")
# Out:
# Initilize JVnSenSegmenter ...
# Reading options ...
# Reading options completed!
# Reading the context predicate maps ...
# Reading context predicate maps (3326 entries) completed!
# Reading the context predicate maps ...
# Reading label maps (2 entries) completed!
# Reading dictionary ...
# Reading dictionary (3328 entries) completed!
# Reading features ...
# Reading 3908 features completed!
# numFetures: 3908
# Reading the context predicate maps ...
# Reading context predicate maps (3326 entries) completed!
# Reading the context predicate maps ...
# Reading label maps (2 entries) completed!
# Reading dictionary ...
# Reading dictionary (3328 entries) completed!
# Reading features ...
# Reading 3908 features completed!
# numFetures: 3908
# Initilize JVnSegmenter ...
# models/jvnsegmenter
# Reading options ...
# Reading options completed!
# Reading the context predicate maps ...
# Reading context predicate maps (292546 entries) completed!
# Reading label maps ...
# Reading label maps (3 entries) completed!
# Reading dictionary ...
# Reading dictionary (292546 entries) completed!
# Number of features: 329757
# Reading features ...
# Reading 329757 features completed!

# %%
gg = []
for sentence in test["sentence"]:
    res = sl.doSenLevel(javaclass_String(sentence))
    gg.append(float(res.getScore()))
# Out:
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# Inference 12 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# sequence 24
# sequence 25
# sequence 26
# sequence 27
# sequence 28
# sequence 29
# sequence 30
# sequence 31
# sequence 32
# sequence 33
# sequence 34
# Inference 34 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# Inference 23 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# Inference 14 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# Inference 15 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# Inference 15 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# Inference 21 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# Inference 13 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# Inference 13 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# sequence 24
# sequence 25
# sequence 26
# sequence 27
# sequence 28
# sequence 29
# sequence 30
# sequence 31
# sequence 32
# sequence 33
# Inference 33 sequences completed!
# Inference time: 0.002 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# Inference 17 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# Inference 19 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# Inference 18 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# Inference 17 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# Inference 20 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# Inference 13 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# sequence 24
# sequence 25
# sequence 26
# sequence 27
# sequence 28
# sequence 29
# sequence 30
# sequence 31
# Inference 31 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# sequence 24
# Inference 24 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# Inference 12 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# Inference 13 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# sequence 24
# sequence 25
# sequence 26
# sequence 27
# sequence 28
# sequence 29
# sequence 30
# sequence 31
# sequence 32
# sequence 33
# sequence 34
# sequence 35
# sequence 36
# sequence 37
# sequence 38
# sequence 39
# sequence 40
# sequence 41
# sequence 42
# Inference 42 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# Inference 12 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# Inference 12 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# Inference 15 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# ...
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# Inference 12 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# Inference 13 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# Inference 15 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# Inference 11 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# sequence 17
# sequence 18
# sequence 19
# sequence 20
# sequence 21
# sequence 22
# sequence 23
# sequence 24
# sequence 25
# sequence 26
# sequence 27
# Inference 27 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# sequence 15
# sequence 16
# Inference 16 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# Inference 10 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# sequence 10
# sequence 11
# sequence 12
# sequence 13
# sequence 14
# Inference 14 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# Inference 8 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# Inference 7 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# Inference 6 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# Inference 4 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# sequence 6
# sequence 7
# sequence 8
# sequence 9
# Inference 9 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# Inference 2 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# sequence 4
# sequence 5
# Inference 5 sequences completed!
# Inference time: 0.0 seconds
# Starting inference ...
# sequence 1
# sequence 2
# sequence 3
# Inference 3 sequences completed!
# Inference time: 0.001 seconds
# Starting inference ...
# sequence 1
# Inference 1 sequences completed!
# Inference time: 0.0 seconds

# %%
print(predictions[:10])
# Out:
# [{'label': 'LABEL_1', 'score': 0.9333884119987488}, {'label': 'LABEL_1', 'score': 0.9455210566520691}, {'label': 'LABEL_1', 'score': 0.9404779076576233}, {'label': 'LABEL_1', 'score': 0.843597948551178}, {'label': 'LABEL_0', 'score': 0.9273842573165894}, {'label': 'LABEL_1', 'score': 0.8446128964424133}, {'label': 'LABEL_0', 'score': 0.9390023946762085}, {'label': 'LABEL_0', 'score': 0.9360643625259399}, {'label': 'LABEL_0', 'score': 0.8957539200782776}, {'label': 'LABEL_0', 'score': 0.9370844960212708}]

# %%
combined = predictions.copy()
for i in range(len(predictions)):
    if (predictions[i]["score"] < 0.6):
        if gg[i] > 0:
            combined[i]["label"] = "LABEL_0"
        elif gg[i] < 0:
            combined[i]["label"] = "LABEL_1"

# %%
low_confidences = []
for i in range(len(predictions)):
    if (predictions[i]["score"] < 0.6):
        low_confidences.append(i)

with open("low_confidences.txt", "w") as f:
    for i in low_confidences:
        f.write(test["sentence"][i] + "\n")
        f.write(str(predictions[i]) + "\n")
        f.write(str(gg[i]) + "\n")
        f.write("LABEL_" + str(test["labels"][i]) + "\n")

# %%
combined = [int(prediction["label"].replace("LABEL_", "")) for prediction in combined]
accuracy.compute(predictions=combined, references=test["labels"])
# Out:
# {'accuracy': 0.899875}
